# %% [markdown]
# #  一 、实验环境配置
#
# ## 1.1 Python安装
# 官网：https://www.python.org/downloads/ 下载任意3.6以上版本，如下载最新版本
#
# 注意软件安装位置，注意勾选把路径，添加到系统变量。
#
# 其它按推荐方式下一步。
#
# ![image.png](attachment:b603a587-bc18-4995-8752-09c456e4fdc0.png)

# %% [markdown]
# 检查Python编译器是否正常安装。
#
# 在CMD命令行中输入python,能够进入交互环境。
#
# 或者在VSCode/Pycharm 集成开发环境(IDE)能否检索到编译器。
#
# ![image.png](attachment:8b54c838-8539-48e0-99d1-9c4eed186a3d.png)

# %%
# !python -m pip config set global.index-url https://pypi.tuna.tsinghua.edu.cn/simple
# Out:
# Writing to C:\Users\mr_menand\AppData\Roaming\pip\pip.ini

# %% [markdown]
# ## 1.2 pip切换国内源
# **pip 是 Python包管理工具**，conda 是一个开源的软件包管理系统和环境管理系统。
#
# 本课程使用pip进行Python包管理，如需虚拟环境开发，推荐 `pip + pyenv`方式。
#
# `python -m pip ...` 其中python是指定版本Python,
#
# 如存在多个版本Python编译器，注意Python版本，通过`whereis python`查询。
#
# 如只有一个版本Python，可省略python -m。

# %% [markdown]
# pip常见用法
#
# - 安装 `pip install requests`
# - 指定版本`pip install request==版本号 `
# - 卸载 `pip uninstall requests`
# - 升级 `pip install --upgrade requests`

# %% [markdown]
# ## 1.3 通过pip安装机器学习必备包
# - 编译开发环境：Jupyter Lab、VS Code
# - 数值计算：Numpy Pandas
# - 绘图：Matplotlib Seaborn
# - 机器学习开发包：Scikit-Learn

# %%
# !python -m pip install jupyterlab

# %%
# !python -m pip install numpy pandas
# !python -m pip install matplotlib seaborn 
# !python -m pip install scikit-learn

# %% [markdown]
# **检查Jupyter Lab是否正常安装**
#
# CMD命令行输入`jupyter lab`
#
# 浏览器会自动打开，或者单击链接，注意不要关闭命令行（后台运行）。
# ![image.png](attachment:aa654b92-aa71-446b-b517-37b995e1eb4f.png)

# %% [markdown]
# **集成开发环境IDE: VSCODE(推荐)或者Pycharm**
#
# 下载：https://code.visualstudio.com/
#
# 安装： 推荐方式，下一步即可。
#
# 安装python扩展后，右下角配置Jupyter lab本地服务器。
#
# ![image.png](attachment:801c1b20-54c1-407a-b1cc-495d5ed886ac.png)

# %% [markdown]
# ## 1.4 作业
#
# 导入相应包，检查上述库是否成功安装，并输入姓名和学号。

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression  

print("姓名：张三")
print("学号：XXXXX")
# Out:
# 姓名：张三
# 学号：XXXXX

# %% [markdown]
# ## 1.5  出现的问题
#
# - 安装JupyterLab的命令是`pip install jupyterlab`
# - CMD命令行上输出 `jupyter lab`
# - CMD不要关(后台运行)，关了浏览器会报错
